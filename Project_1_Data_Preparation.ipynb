# %% [markdown]
# <a href="https://colab.research.google.com/github/SaurabhVaze/sales-prediction/blob/main/Project_1_Data_Preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 1 - Part 2
#
# Saurabh Vaze
#
# 05/26/22

# %%
import pandas as pd
import numpy as np

sales_df = pd.read_csv('/content/sales_predictions.csv')

# %%
sales_df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
sales_df.shape # 1. number of rows/columns
# Out:
# (8523, 12)

# %%
sales_df.info()  # 2. What are the datatypes of each variable?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
sales_df.duplicated().sum()        # 3. Are there duplicates? If so, drop any duplicates.
# Out:
# 0

# %%
sales_df.isna().sum()      # 4. Identify missing values
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# 5. Decide on how to address the missing values and do it! 
sales_df.groupby(['Outlet_Type'])['Outlet_Size'].value_counts() #find possible correlation between outlet type and size (which has many missing values)
# Out:
# Outlet_Type        Outlet_Size
# Grocery Store      Small           528
# Supermarket Type1  Small          1860
#                    High            932
#                    Medium          930
# Supermarket Type2  Medium          928
# Supermarket Type3  Medium          935
# Name: Outlet_Size, dtype: int64

# %%
sales_df.drop(columns='Outlet_Size', inplace=True) #Drop Outlet Size column because Outlet_Type can reflect similar insight with high correlation regarding size of the store

# %%
mean_weight= sales_df['Item_Weight'].mean() # Replace missing Item Weight with Column average
sales_df['Item_Weight'].fillna(mean_weight, inplace=True)

# %%
sales_df.isna().sum() # 6. No remaining missing values
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
sales_df.sample(50) #find columns with irregular column values
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDN60    15.100000          Low Fat         0.095546
# 6182           NCW17    18.000000          Low Fat         0.019383
# 8306           FDV50    14.300000          Low Fat         0.122762
# 7043           NCI29     8.600000          Low Fat         0.032615
# 1249           FDC32    18.350000          Low Fat         0.099310
# 6053           FDB28     6.615000          Low Fat         0.093308
# 6110           FDR52    12.650000          Regular         0.076475
# 1565           FDE16    12.857645          Low Fat         0.026216
# 2828           FDC08    19.000000          Regular         0.103611
# 6684           FDE33    19.350000          Regular         0.083080
# 4774           NCK30    14.850000          Low Fat         0.061102
# 1047           DRN11     7.850000          Low Fat         0.162980
# 4241           DRJ25    14.600000          Low Fat         0.150873
# 2809           FDD17     7.500000          Low Fat         0.054611
# 7578           FDC47    15.000000          Low Fat         0.118868
# 4536           NCD06    13.000000          Low Fat         0.099480
# 1347           FDD50    18.850000          Low Fat         0.141524
# 6016           NCY30    20.250000          Low Fat         0.025932
# 8380           FDI19    15.100000          low fat         0.000000
# 2762           NCP18    12.150000          Low Fat         0.028593
# 2343           FDM33    15.600000          Low Fat         0.088216
# 5177           FDU12    12.857645          Regular         0.075384
# 380            FDX31    12.857645          Regular         0.014754
# 3967           FDV59    13.350000          Low Fat         0.048018
# 6495           FDG52    12.857645          Low Fat         0.065313
# 1276           FDF24    15.500000          Regular         0.025366
# 7079           FDW51     6.155000          Regular         0.095045
# 105            FDH14    17.100000          Regular         0.046770
# 2644           FDO04    16.600000          Low Fat         0.000000
# 3601           FDH47    13.500000          Regular         0.128816
# 4146           DRZ24     7.535000          Low Fat         0.081788
# 8111           DRJ35    10.100000          Low Fat         0.046848
# 4115           FDP31    12.857645          Regular         0.160723
# 7778           NCK29     5.615000               LF         0.000000
# 6577           NCR41    17.850000          Low Fat         0.018126
# 4441           FDB35    12.300000          Regular         0.064619
# 6474           FDE56    17.250000          Regular         0.159165
# 5331           FDE44    14.650000          Low Fat         0.171356
# 2198           FDX49     4.615000          Regular         0.101813
# 3843           FDU34    18.250000          Low Fat         0.075501
# 3360           FDU32     8.785000          Low Fat         0.000000
# 5131           NCD18    16.000000          Low Fat         0.072655
# 7430           NCO42    21.250000          Low Fat         0.024694
# 2353           FDR10    17.600000          Low Fat         0.010038
# 5873           DRL49    13.150000          Low Fat         0.056418
# 4920           FDO11     8.000000          Regular         0.050657
# 7634           FDM25    10.695000          Regular         0.061009
# 5745           FDO31    12.857645          Regular         0.028842
# 4166           FDC50    15.850000          Low Fat         0.137270
# 3867           FDY38    13.600000          Regular         0.119077
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 5676           Baking Goods  157.3604            OUT018
# 6182     Health and Hygiene  129.3994            OUT035
# 8306                  Dairy  124.3730            OUT049
# 7043     Health and Hygiene  142.9154            OUT035
# 1249  Fruits and Vegetables   91.4462            OUT045
# 6053                  Dairy  195.9426            OUT013
# 6110           Frozen Foods  191.8846            OUT017
# 1565           Frozen Foods  207.5954            OUT027
# 2828  Fruits and Vegetables  228.3720            OUT049
# 6684  Fruits and Vegetables   80.3644            OUT010
# 4774              Household  253.2698            OUT045
# 1047            Hard Drinks  145.2444            OUT046
# 4241            Soft Drinks   47.5692            OUT045
# 2809           Frozen Foods  237.1906            OUT010
# 7578            Snack Foods  229.4694            OUT035
# 4536              Household   44.9060            OUT049
# 1347                 Canned  168.4132            OUT013
# 6016              Household  182.5976            OUT013
# 8380                   Meat  244.2512            OUT045
# 2762              Household  151.0708            OUT035
# 2343            Snack Foods  220.1798            OUT017
# 5177           Baking Goods  262.7568            OUT027
# 380   Fruits and Vegetables  231.7958            OUT027
# 3967                 Breads  219.6166            OUT035
# 6495           Frozen Foods   47.1402            OUT027
# 1276           Baking Goods   82.7934            OUT035
# 7079                   Meat  213.4560            OUT018
# 105                  Canned  141.1838            OUT013
# 2644           Frozen Foods   54.6614            OUT017
# 3601          Starchy Foods   96.4068            OUT046
# 4146            Soft Drinks  120.8440            OUT046
# 8111            Hard Drinks   60.6878            OUT017
# 4115  Fruits and Vegetables   65.7168            OUT027
# 7778     Health and Hygiene  121.9730            OUT046
# 6577     Health and Hygiene   94.9094            OUT017
# 4441          Starchy Foods   89.8804            OUT046
# 6474  Fruits and Vegetables   63.4194            OUT035
# 5331  Fruits and Vegetables   47.6692            OUT035
# 2198                 Canned  232.2300            OUT035
# 3843            Snack Foods  123.1046            OUT018
# 3360  Fruits and Vegetables  120.5414            OUT013
# 5131              Household  229.8668            OUT035
# 7430              Household  144.1102            OUT049
# 2353            Snack Foods  163.5552            OUT035
# 5873            Soft Drinks  142.4812            OUT035
# 4920                 Breads  249.9092            OUT010
# 7634              Breakfast  177.5712            OUT017
# 5745  Fruits and Vegetables   81.4960            OUT027
# 4166                 Canned   94.4094            OUT017
# 3867                  Dairy  231.2300            OUT013
#
#       Outlet_Establishment_Year Outlet_Location_Type        Outlet_Type  \
# 5676                       2009               Tier 3  Supermarket Type2
# 6182                       2004               Tier 2  Supermarket Type1
# 8306                       1999               Tier 1  Supermarket Type1
# 7043                       2004               Tier 2  Supermarket Type1
# 1249                       2002               Tier 2  Supermarket Type1
# 6053                       1987               Tier 3  Supermarket Type1
# 6110                       2007               Tier 2  Supermarket Type1
# 1565                       1985               Tier 3  Supermarket Type3
# 2828                       1999               Tier 1  Supermarket Type1
# 6684                       1998               Tier 3      Grocery Store
# 4774                       2002               Tier 2  Supermarket Type1
# 1047                       1997               Tier 1  Supermarket Type1
# 4241                       2002               Tier 2  Supermarket Type1
# 2809                       1998               Tier 3      Grocery Store
# 7578                       2004               Tier 2  Supermarket Type1
# 4536                       1999               Tier 1  Supermarket Type1
# 1347                       1987               Tier 3  Supermarket Type1
# 6016                       1987               Tier 3  Supermarket Type1
# 8380                       2002               Tier 2  Supermarket Type1
# 2762                       2004               Tier 2  Supermarket Type1
# 2343                       2007               Tier 2  Supermarket Type1
# 5177                       1985               Tier 3  Supermarket Type3
# 380                        1985               Tier 3  Supermarket Type3
# 3967                       2004               Tier 2  Supermarket Type1
# 6495                       1985               Tier 3  Supermarket Type3
# 1276                       2004               Tier 2  Supermarket Type1
# 7079                       2009               Tier 3  Supermarket Type2
# 105                        1987               Tier 3  Supermarket Type1
# 2644                       2007               Tier 2  Supermarket Type1
# 3601                       1997               Tier 1  Supermarket Type1
# 4146                       1997               Tier 1  Supermarket Type1
# 8111                       2007               Tier 2  Supermarket Type1
# 4115                       1985               Tier 3  Supermarket Type3
# 7778                       1997               Tier 1  Supermarket Type1
# 6577                       2007               Tier 2  Supermarket Type1
# 4441                       1997               Tier 1  Supermarket Type1
# 6474                       2004               Tier 2  Supermarket Type1
# 5331                       2004               Tier 2  Supermarket Type1
# 2198                       2004               Tier 2  Supermarket Type1
# 3843                       2009               Tier 3  Supermarket Type2
# 3360                       1987               Tier 3  Supermarket Type1
# 5131                       2004               Tier 2  Supermarket Type1
# 7430                       1999               Tier 1  Supermarket Type1
# 2353                       2004               Tier 2  Supermarket Type1
# 5873                       2004               Tier 2  Supermarket Type1
# 4920                       1998               Tier 3      Grocery Store
# 7634                       2007               Tier 2  Supermarket Type1
# 5745                       1985               Tier 3  Supermarket Type3
# 4166                       2007               Tier 2  Supermarket Type1
# 3867                       1987               Tier 3  Supermarket Type1
#
#       Item_Outlet_Sales
# 5676          4436.8912
# 6182          3340.9844
# 8306          2093.9410
# 7043           992.7078
# 1249          1665.8316
# 6053          2570.6538
# 6110          1146.5076
# 1565          6668.6528
# 2828           905.4880
# 6684           157.1288
# 4774          2283.0282
# 1047          1451.4440
# 4241          1379.5376
# 2809           237.6906
# 7578          5937.6044
# 4536           652.4840
# 1347          2874.9244
# 6016          3078.6592
# 8380          3635.2680
# 2762          2858.9452
# 2343          5068.7354
# 5177          7646.0472
# 380           5375.0034
# 3967          3483.4656
# 6495          1516.0266
# 1276          1228.4010
# 7079          2556.6720
# 105           2247.7408
# 2644           884.1824
# 3601          2527.3768
# 4146          2157.1920
# 8111           363.5268
# 4115          2237.0880
# 7778          2463.4600
# 6577           761.6752
# 4441          1286.3256
# 6474          1547.9850
# 5331           739.0380
# 2198          5126.6600
# 3843           249.0092
# 3360          1583.9382
# 5131          4837.7028
# 7430          1749.7224
# 2353          3086.6488
# 5873          2422.1804
# 4920           249.0092
# 7634          2636.5680
# 5745          1997.4000
# 4166          1904.1880
# 3867          2330.3000

# %%
sales_df['Item_Fat_Content'].value_counts() # irregular labelling in Fat Content classification
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
sales_df['Item_Fat_Content']= sales_df['Item_Fat_Content'].replace(['LF','low fat'], 'Low Fat')  #replace 'LF' and 'low fat' labels

# %%
sales_df['Item_Fat_Content'] = sales_df['Item_Fat_Content'].replace('reg', 'Regular') # Replace 'reg' label

# %%
sales_df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
nums = sales_df.filter(['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales'], axis = 1) # new df of only numerical columns from sales_df

# %%
nums.describe().round(2) # statistics of numerical columns
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# count      8523.00          8523.00   8523.00            8523.00
# mean         12.86             0.07    140.99            2181.29
# std           4.23             0.05     62.28            1706.50
# min           4.56             0.00     31.29              33.29
# 25%           9.31             0.03     93.83             834.25
# 50%          12.86             0.05    143.01            1794.33
# 75%          16.00             0.09    185.64            3101.30
# max          21.35             0.33    266.89           13086.96
